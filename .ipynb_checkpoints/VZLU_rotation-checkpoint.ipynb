# %% [markdown]
# ### set1 - flare

# %%
import numpy as np
data=np.genfromtxt("/home/limu/Space/data/atti/vzlusat2_aocs1.csv",delimiter=',',skip_header=1).T

# %%
from matplotlib import pyplot as pl
# %matplotlib inline

tim=data[0]-data[0][0]
pl.plot(tim,data[-1])
pl.savefig("/tmp/plot1.eps")

# %%
pl.plot(tim,data[1])

# %%
pl.plot(tim,data[1],'s-')
#pl.xlim(3000,4300)

# %%
data.shape
import os
os.listdir("/home/limu/Space/data/atti/")
# Out:
# ['vzlusat2_aocs1.csv', 'vzlusat2_burst_june.csv']

# %%
from scipy.spatial import transform as spt
mat100=[]
idx100=[]
agood=np.where(np.isnan(data[1])==False)[0]
for k in agood:
    #if data[1,k]==np.nan: 
    #    continue
    try:
        mat100.append(spt.Rotation.from_quat(data[1:5,k]).as_matrix())
    except:
        continue
    idx100.append(k)
matsel=np.array(mat100)
len(idx100)
# Out:
# 358

# %%
timsel=tim[idx100]
matsel.shape
# Out:
# (358, 3, 3)

# %%
ang_zp_fly=np.rad2deg(np.arccos(matsel[:,2,0]))
pl.plot(timsel,ang_zp_fly,'s-')

# %%
#matsel=np.array([spt.Rotation.from_quat(data[1:5,k]).as_matrix() for k in range(300,430)  if data[1,k]!=np.nan])
data[5:,agood[jind]]
# Out:
# array([3.43823606e+01, 2.28245930e+01, 3.94159100e+01, 2.27890362e+01,
#        5.41079768e+05])

# %%
jind=1
b2lv=spt.Rotation.from_quat(data[1:5,agood[jind]])
from datetime import datetime
x=datetime.fromtimestamp(data[0,agood[jind]])

b2lv.as_matrix()
# Out:
# array([[-0.71207721,  0.23847869,  0.66035896],
#        [ 0.58760708,  0.71720066,  0.37462131],
#        [-0.38427068,  0.6547909 , -0.65083402]])

# %%
import predict
pos=data[5:,agood[jind]]
qth=list(pos[:2])+[0]
tle='''VZLUSAT2
1 51085U 22002BF  22150.70473102  .00004963  00000-0  28884-3 0  9994
2 51085  97.4865 217.8168 0015989 133.4617 325.2380 15.12382761 20719'''
mypos=predict.observe(tle, qth, at=data[0,agood[jind]])
#eloc2cart(satel)

# %%
import astropy.coordinates as coor
import astropy.units as u
eloc2cart=lambda k: np.array([k.x.value,k.y.value,k.z.value])
cart2angle=lambda p:[np.rad2deg(np.arcsin(p[2])),np.rad2deg(np.arctan2(p[1],p[0]))]
norm=lambda v:np.sqrt(np.dot(v,v))

def get_look(pos,tx):
    inter=coor.EarthLocation(lon=pos[1]*u.deg,lat=pos[0]*u.deg) #ground
    satel=coor.EarthLocation(lon=pos[3]*u.deg,lat=pos[2]*u.deg,height=pos[4]*u.m)

    look=eloc2cart(satel)-eloc2cart(inter)
    #coor.SkyCoord(*[l*u.km for l in look]) x=look[0],y=look[1],z=look[2]
    dec,ra=cart2angle(look/norm(look))
    alook=coor.SkyCoord(ra,dec,frame='icrs',unit='deg')#[l*u.m for l in look],representation_type='cartesian', frame="icrs")
    alook.location=satel
    alook.obstime=tx
    return alook
alook2=get_look(data[5:,agood[jind]],x)
alook2.altaz
# Out:
# <SkyCoord (AltAz: obstime=2022-05-20 20:02:53, location=(4934350.49877974, 2073098.9920879, 4371651.17911943) m, pressure=0.0 hPa, temperature=0.0 deg_C, relative_humidity=0.0, obswl=1.0 micron): (az, alt) in deg
#     (0.09658123, 33.54613036)>

# %%
alook.altaz
# Out:
# <SkyCoord (AltAz: obstime=2022-05-20 22:02:53, location=(4934350.49877974, 2073098.9920879, 4371651.17911943) m, pressure=0.0 hPa, temperature=0.0 deg_C, relative_humidity=0.0, obswl=1.0 micron): (az, alt) in deg
#     (3.64282836, 34.31860327)>

# %%
from datetime import datetime
x=datetime.fromtimestamp(data[0,agood[jind]])

# %%
alook.location=satel
alook.obstime=x
alook.altaz
# Out:
# <SkyCoord (AltAz: obstime=2022-05-20 22:02:53, location=(4930490.86188263, 4052244.23310898, 2664778.51862992) m, pressure=0.0 hPa, temperature=0.0 deg_C, relative_humidity=0.0, obswl=1.0 micron): (az, alt) in deg
#     (336.84758429, -48.59502226)>

# %%
from astropy.time import Time
asun=coor.get_sun(Time(x))
asun.location=satel
asun.altaz
# Out:
# <SkyCoord (AltAz: obstime=2022-05-20 20:02:53, location=(4934350.49877974, 2073098.9920879, 4371651.17911943) m, pressure=0.0 hPa, temperature=0.0 deg_C, relative_humidity=0.0, obswl=1.0 micron): (az, alt, distance) in (deg, deg, AU)
#     (323.89703127, -21.80522226, 1.01195262)>

# %%
# Out:
# 1

# %%
import pytz
tz=pytz.timezone("UTC")
from datetime import datetime
x=datetime.fromtimestamp(data[0,agood[jind]],tz=tz)
(Time(x)-Time(data[0,agood[jind]],format='unix',scale='utc')).value*24
# Out:
# 0.0

# %%
pos2=[mypos[a] for a in ['longitude','latitude','altitude']]
satpos2=coor.EarthLocation.from_geodetic(lon=pos2[0]*u.deg,lat=pos2[1]*u.deg,height=pos2[2]*u.km)
satpos2.to_geodetic()
# Out:
# GeodeticLocation(lon=<Longitude 22.81029062 deg>, lat=<Latitude 39.3395065 deg>, height=<Quantity 541.63364879 km>)

# %%
def get_fly(time,satpos=None):
    '''fly direction from pypredict
    '''
    mypos=predict.observe(tle, qth, at=time.timestamp())
    pos=[mypos[a] for a in ['longitude','latitude','altitude']]
    fly=np.array([mypos['eci_v'+a] for a in list('xyz')])
    flsp=norm(fly)
    vdec,vra=cart2angle(fly/flsp)
    if satpos==None: satpos=coor.EarthLocation(lon=pos[0]*u.deg,lat=pos[1]*u.deg,height=pos[2]*u.km)
    sfly=coor.SkyCoord(vra*u.deg,vdec*u.deg,frame='icrs',location=satpos,obstime=time)
    return sfly.altaz

# %%
mfly=get_fly(x,satel)

# %%
su.norm(su.eloc2cart(satel))-550000
# Out:
# 6360635.883021189

# %%
mfly.altaz
# Out:
# <SkyCoord (AltAz: obstime=2022-05-20 20:02:53, location=(4934350.49877974, 2073098.9920879, 4371651.17911943) m, pressure=0.0 hPa, temperature=0.0 deg_C, relative_humidity=0.0, obswl=1.0 micron): (az, alt) in deg
#     (350.10143906, 0.2464024)>

# %%
#get_fly(x)
import satutils as su 
su.triad
v1=-su.eloc2cart(satel)
v1/=su.norm(v1)
u2=su.eloc2cart(mfly.cartesian)

# %%
v1@v2,u1@u2
# Out:
# (-0.9679504711776604, -0.0043005199854627175)

# %%
v2=su.eloc2cart(mfly.icrs.cartesian)
mat1=su.triad(v1,v2)
mat1 #LVLH in ECI
# Out:
# array([[-0.71402264, -0.29998672, -0.63259753],
#        [ 0.07047651,  0.86816584, -0.49124448],
#        [ 0.69656638, -0.39534295, -0.59874805]])

# %%
su.eloc2cart(coor.AltAz(-90*u.deg,0*u.deg).cartesian)
# Out:
# array([-1.8369702e-16, -1.0000000e+00,  0.0000000e+00])

# %%
u1=np.array([0,0,-1])
mat2=su.triad(u1,u2)
mat2
# Out:
# array([[ 0.        ,  0.        , -1.        ],
#        [-0.17190436, -0.98511364, -0.        ],
#        [-0.98511364,  0.17190436,  0.        ]])

# %%
#mat2.dot(alook)
bloo2=su.eloc2cart(alook.altaz.cartesian)
bloo1=su.eloc2cart(alook.icrs.cartesian)

# %%
mat1.T@bloo1,mat2.T@bloo2
# Out:
# (array([ 0.62565833, -0.39074539, -0.67518122]),
#  array([-0.56442222,  0.04522408, -0.82424653]))

# %%
#alook.separation(get_fly(x,satel))cartesian
# Out:
# <Angle 34.59749114 deg>

# %%
#fly vector 100 seconds later
from datetime import timedelta
get_fly(x+timedelta(0,1000))
# Out:
# <SkyCoord (AltAz: obstime=2022-05-20 22:19:33, location=(-1001.13628905, -1428.79346856, 6671.16189131) km, pressure=0.0 hPa, temperature=0.0 deg_C, relative_humidity=0.0, obswl=1.0 micron): (az, alt) in deg
#     (239.68222366, -5.30609744)>

# %%
z0=datetime(2022, 5, 20, 22, 10, 0).timestamp()
dz=z0-data[0][0]
pl.plot(tim,data[1],'s-')
pl.xlim(dz-100,dz+100)
pl.axvline(dz,color='r')

# %%
#j=sum(data[0]<z0)
b2lv=spt.Rotation.from_quat(data[1:5,agood[jind]])
b2lv.as_matrix()
# Out:
# array([[-0.71207721,  0.23847869,  0.66035896],
#        [ 0.58760708,  0.71720066,  0.37462131],
#        [-0.38427068,  0.6547909 , -0.65083402]])

# %%
data[1:5,agood[jind]]
# Out:
# array([-0.23534875, -0.87751238, -0.2932757 , -0.29761108])

# %%
b2lv.as_euler('xyx')#.apply([0,0,1])
# Out:
# array([0.34655994, 2.36324868, 0.99164332])

# %%
fly_vec=get_fly(x)
fly_vec
# Out:
# <SkyCoord (AltAz: obstime=2022-05-20 20:02:53, location=(4939.35864164, 2077.35915933, 4364.88774711) km, pressure=0.0 hPa, temperature=0.0 deg_C, relative_humidity=0.0, obswl=1.0 micron): (az, alt) in deg
#     (350.11491251, 0.1683124)>

# %%
fly_vec.cartesian
# Out:
# <CartesianRepresentation (x, y, z) [dimensionless]
#     (0.98514979, -0.17167196, 0.0029376)>

# %% [markdown]
# ### set 2 - Burst

# %%
#data=np.genfromtxt("/home/limu/Space/data/atti/vzlusat2_burst_june.csv",delimiter=',',skip_header=1).T
data=np.genfromtxt("/home/limu/Space/data/atti/vzlusat2_orientation_dec15b.csv",delimiter=',',skip_header=1).T

# %%
cols='timestamp,qbl0,qbl1,qbl2,qbl3,qbn0,qbn1,qbn2,qbn3,dir_lat,dir_lon,sat_lat,sat_lon,sat_alt,sat_pos_x,sat_pos_y,sat_pos_z,sat_vel_x,sat_vel_y,sat_vel_z,sat_x_alpha,sat_x_delta,sat_y_alpha,sat_y_delta,sat_z_alpha,sat_z_delta'.split(',')
cols[11:14]
# Out:
# ['sat_lat', 'sat_lon', 'sat_alt']

# %%
good=np.isnan(data[-6])==False
xra,xdec=data[-6:-4,good]
yra,ydec=data[-4:-2,good]
zra,zdec=data[-2:,good]
quats=data[1:5,good].T

# %%
time=data[0,good]-data[0][0]
pl.plot(time,np.rad2deg(xra))

# %%
import scoords
import astropy.units as u
from astropy.coordinates import SkyCoord, EarthLocation
from astropy.time import Time
from datetime import datetime


i=10
at1=scoords.Attitude.from_quat(quats[i])
c1=SkyCoord(ra = xra[i]*u.rad, dec = xdec[i]*u.rad)
c2=SkyCoord(ra = yra[i]*u.rad, dec = ydec[i]*u.rad)
c3=SkyCoord(ra = zra[i]*u.rad, dec = zdec[i]*u.rad)
obs1=Time(datetime.fromtimestamp(data[0][0]+time[i]))
sat0=EarthLocation.from_geodetic(lon=lon[i]*u.deg, lat=lat[i]*u.deg, height=alti[i]*u.m)
frame = scoords.SpacecraftFrame(attitude=at1,obstime=obs1,location=sat0)

# %%
toangle=lambda p:[np.rad2deg(np.arcsin(p[2])),np.rad2deg(np.arctan2(p[1],p[0]))]
cors=np.cross(vel[i]/nvel[i],pos[i]/nrad[i])
a1,a2=toangle(vel[i]/nvel[i])
b1,b2=toangle(-pos[i]/nrad[i])
q1,q2=toangle(cors)
veldir=SkyCoord(dec=a1*u.deg,ra=a2*u.deg)#.from_pixel(vel[i][0]*u.m,vel[i][1]*u.m,vel[i][2]*u.m)
nadir=SkyCoord(dec=b1*u.deg,ra=b2*u.deg)#.from_pixel(vel[i][0]*u.m,vel[i][1]*u.m,vel[i][2]*u.m)
pedir=SkyCoord(dec=q1*u.deg,ra=q2*u.deg)#.from_pixel(vel[i][0]*u.m,vel[i][1]*u.m,vel[i][2]*u.m)
pedir.separation(c1).degree
# Out:
# 118.51605224469358

# %%
vel,pos=data[-9:-6,good].T,data[14:17,good].T
nvel=np.sqrt((vel**2).sum(1))
nrad=np.sqrt((pos**2).sum(1))
lat,lon,alti=data[11:14,good]

# %% [markdown]
# Triad of vectors
#
# - veldir
# - pedir = nadir x veldir
# - nadir
#
# at1 matrix transforms XYZ into this (?)

# %%
doval=lambda p:np.array([p.x.value,p.y.value,p.z.value])
matZ=np.array([doval(v.cartesian) for v in [veldir,pedir,nadir]])
matO=np.array([doval(v.cartesian) for v in [c1,c2,c3]])

# %%
# calculate angles

XYZangles=[toangle(a)[::-1] for a in (np.linalg.inv(matZ)@at1.as_matrix()).T]

# %%
qang=90-np.rad2deg(np.arccos(np.sum(vel*pos,1)/nvel[i]/nrad[i]))

# %%
norm=lambda p:p/np.sqrt((p**2).sum())
    
for i in range(90):
    sat0=EarthLocation.from_geodetic(lon=lon[i]*u.deg, lat=lat[i]*u.deg, height=alti[i]*u.m)
    cc=sat0.to_geocentric()
    print(np.dot(pos[i]/nrad[i],norm(np.array([cc[j].value for j in range(3)]))))
# Out:
# 0.9644781466813223
# 0.9664330226918578
# 0.9679583307858197
# 0.9690529732490514
# 0.9697160625659907
# 0.9699469220096182
# 0.9697450861278837
# 0.9691103011262591
# 0.968042525146114
# 0.9665419284386684
# 0.9646088934343389
# 0.9622440147073156
# 0.959448098835276
# 0.9562221641542209
# 0.9525674404084749
# 0.9484853682957531
# 0.9439775989076934
# 0.9390459930657581
# 0.9336926205528358
# 0.9279197592409072
# 0.9217298941149238
# 0.9151257161934282
# 0.9081101213462801
# 0.9006862090099639
# 0.8928572808010955
# 0.8846268390285769
# 0.8759985851052453
# 0.8669764178594861
# 0.857564431747651
# 0.8477669149682263
# 0.8375883474781906
# 0.8270333989130683
# 0.8161069264108792
# 0.8048139723417383
# 0.7931597619435249
# 0.7811497008651906
# 0.7687893726183216
# 0.7560845359387673
# 0.743041122059253
# 0.7296652318939668
# 0.715963133136859
# 0.7019412572752791
# 0.687606196519444
# 0.6729647006501315
# 0.6580236737855915
# 0.6427901710694571
# 0.6272713952809229
# ...

# %%
np.sqrt(sum(np.array([cc[i].value for i in range(3)])**2))/nrad[10]
# Out:
# 0.9997873534325112
